# %% [markdown]
# <center><img src="https://github.com/DACSS-CSSmeths/guidelines/blob/main/pics/small_logo_ccs_meths.jpg?raw=true" width="700"></center>

# %% [markdown]
# # PRE HOMEWORK

# %% [markdown]
# # Case 3: Fifa 2022 world cup
#
# <a target="_blank" href="https://colab.research.google.com/github/DACSS-CSSmeths/Networks_intro/blob/main/case3.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# Let me use some information about countries from the 2022 [Fifa World Cup](https://en.wikipedia.org/wiki/2022_FIFA_World_Cup_squads). I have added som attributes for the countrues and the clubs with the help from ChatGpt (these attributes may not be accurate).
#
# * For the _club_: if the club was the national champion in its country the year before the world cup
# * For the _country_: if the country  is considered developed or not.

# %%
from IPython.display import IFrame

IFrame('https://docs.google.com/spreadsheets/d/e/2PACX-1vTjk__2p0MTF5Oh_qmJ9PQpk-QN71HXKzxIYBcvKe09YiGYDD9tL1FlZ7BIiAL2rx_4wdF8mOWziGl9/pubhtml', 800, 350)
# Out:
#         <iframe
#             width="800"
#             height="350"
#             src="https://docs.google.com/spreadsheets/d/e/2PACX-1vTjk__2p0MTF5Oh_qmJ9PQpk-QN71HXKzxIYBcvKe09YiGYDD9tL1FlZ7BIiAL2rx_4wdF8mOWziGl9/pubhtml"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Let's use the data from GitHub:

# %%
import pandas as pd

fifaLink = "https://github.com/DACSS-CSSmeths/Networks_intro/raw/refs/heads/main/casesData/fifa2022.xlsx"
fifa=pd.read_excel(fifaLink,sheet_name='fifa2022')
fifa.head()
# Out:
#    idnum pos             name        dob  caps  goals              club group  \
# 0      1  GK  Hernán Galíndez 1987-03-30    12      0             Aucas     A
# 1      2  DF     Félix Torres 1997-01-11    17      2     Santos Laguna     A
# 2      3  DF   Piero Hincapié 2002-01-09    21      1  Bayer Leverkusen     A
# 3      4  DF  Robert Arboleda 1991-10-22    33      2         São Paulo     A
# 4      5  MF   José Cifuentes 1999-03-12    11      0    Los Angeles FC     A
#
#   nationality  age2022
# 0     Ecuador       35
# 1     Ecuador       25
# 2     Ecuador       20
# 3     Ecuador       31
# 4     Ecuador       23

# %% [markdown]
# This shows data for every player in the cup. Let's pay attention to three variables:

# %%
fifa.loc[:,['name','club','nationality']]
# Out:
#                     name                  club nationality
# 0        Hernán Galíndez                 Aucas     Ecuador
# 1           Félix Torres         Santos Laguna     Ecuador
# 2         Piero Hincapié      Bayer Leverkusen     Ecuador
# 3        Robert Arboleda             São Paulo     Ecuador
# 4         José Cifuentes        Los Angeles FC     Ecuador
# ..                   ...                   ...         ...
# 826       Martín Cáceres             LA Galaxy     Uruguay
# 827        Sergio Rochet              Nacional     Uruguay
# 828     Agustín Canobbio  Athletico Paranaense     Uruguay
# 829        Manuel Ugarte           Sporting CP     Uruguay
# 830  José Luis Rodríguez              Nacional     Uruguay
#
# [831 rows x 3 columns]

# %% [markdown]
# Pay attention! ... it is obvious we could have a _bipartite_ network here.
#
# Let's try this one with players and club:

# %%
import networkx as nx

fifanet1 = nx.Graph()
fifanet1.add_nodes_from(fifa.name, bipartite=0) # Add the node attribute "bipartite"
fifanet1.add_nodes_from(fifa.club, bipartite=1) # Add the node attribute "bipartite"
fifanet1.add_edges_from([c for c in zip(fifa.name,fifa.club)])

# %%
from networkx.algorithms import bipartite
players_nodes,clubs_nodes = bipartite.sets(fifanet1)
# Draw bipartite graph
pos = nx.bipartite_layout(fifanet1, players_nodes,align='horizontal',aspect_ratio=1)
color_dict = {0:'b',1:'r'}
color_list = [color_dict[i[1]] for i in fifanet.nodes.data('bipartite')]
nx.draw(fifanet1, pos=pos, with_labels=True, node_color = color_list)
# Out:
# ---------------------------------------------------------------------------
# AmbiguousSolution                         Traceback (most recent call last)
# <ipython-input-7-c27e64f9c3e9> in <cell line: 0>()
#       1 from networkx.algorithms import bipartite
# ----> 2 players_nodes,clubs_nodes = bipartite.sets(fifanet1)
#       3 # Draw bipartite graph
#       4 pos = nx.bipartite_layout(fifanet1, players_nodes,align='horizontal',aspect_ratio=1)
#       5 color_dict = {0:'b',1:'r'}
#
# /usr/local/lib/python3.11/dist-packages/networkx/utils/decorators.py in argmap_sets_1(G, top_nodes, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# /usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py in __call__(self, backend, *args, **kwargs)
#    1353                 if not graph_backend_names or graph_backend_names == {backend_name}:
#    1354                     if self._can_backend_run(backend_name, args, kwargs):
# -> 1355                         return self._call_with_backend(backend_name, args, kwargs)
#    1356                 elif self._can_convert(
#    1357                     backend_name, graph_backend_names
#
# /usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py in _call_with_backend(self, backend_name, args, kwargs, extra_message)
#    1856         """Call this dispatchable function with a backend without converting inputs."""
#    1857         if backend_name == "networkx":
# -> 1858             return self.orig_func(*args, **kwargs)
#    1859         backend = _load_backend(backend_name)
#    1860         _logger.debug(
#
# /usr/local/lib/python3.11/dist-packages/networkx/algorithms/bipartite/basic.py in sets(G, top_nodes)
#     216         if not is_connected(G):
#     217             msg = "Disconnected graph: Ambiguous solution for bipartite sets."
# --> 218             raise nx.AmbiguousSolution(msg)
#     219         c = color(G)
#     220         X = {n for n, is_top in c.items() if is_top}
#
# AmbiguousSolution: Disconnected graph: Ambiguous solution for bipartite sets.

# %% [markdown]
# As you see, here you have a problem with the code
# ```
# players_nodes,clubs_nodes = bipartite.sets(fifanet1)
# ```

# %% [markdown]
# That is bad news. Let me show you an alternative way to that line of code:

# %%
players_nodes = {n for n, d in fifanet1.nodes(data=True) if d["bipartite"] == 0}
clubs_nodes = set(fifanet1) - players_nodes

# %% [markdown]
# Now, draw the graph:

# %%
pos = nx.spring_layout(fifanet1)
color_dict = {0:'b',1:'r'}
color_list = [color_dict[i[1]] for i in fifanet1.nodes.data('bipartite')]
nx.draw(fifanet1, pos=pos, with_labels=False,node_size=5,width=0.5,node_color = color_list)

# %% [markdown]
# As you may have guessed, the clubs divide the players, so in the data we have, it is NOT possible that a player belongs to two clubs. In our example above, an actor can be in more than one movie. If you install pydot you could see this graph:

# %%
# !pip install pydot
import pydot
pos = nx.nx_pydot.graphviz_layout(fifanet1)
nx.draw(fifanet1, pos=pos, with_labels=False, node_size=10, node_color = color_list,width=0.5)
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.11/dist-packages (3.0.4)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.11/dist-packages (from pydot) (3.2.1)

# %% [markdown]
# As this one is not working, do you think "player-country"  would work?
# Prepare it, and test your answer.
#
# Prepare the bipartite "club-country", and create two graphs, one where club is projected, and another where country is projected. What is the meaning of the edges in each case?
#
# Save both projected graphs (weighted) as _graphml_. Include the attributes for the nodes that will be projected.
#
# __________
#
# Go back to the [INTRO](https://dacss-cssmeths.github.io/Networks_intro/)

# %%
fifanet2 = nx.Graph()
fifanet2.add_nodes_from(fifa.name, bipartite=0) # Add the node attribute "bipartite"
fifanet2.add_nodes_from(fifa.nationality, bipartite=1) # Add the node attribute "bipartite"
fifanet2.add_edges_from([c for c in zip(fifa.name,fifa.nationality)])

# %%
players_nodes2 = {n for n, d in fifanet2.nodes(data=True) if d["bipartite"] == 0}
countries_nodes = set(fifanet2) - players_nodes2

# %%
pos = nx.bipartite_layout(fifanet2, players_nodes2)
color_dict = {0:'b',1:'r'}
color_list = [color_dict[i[1]] for i in fifanet2.nodes.data('bipartite')]
nx.draw(fifanet2, pos=pos, with_labels=False,node_size=5,width=0.3,node_color = color_list)

# %% [markdown]
# 2. Prepare the bipartite "club-country", and create two graphs, one where club is projected, and another where country is projected. What is the meaning of the edges in each case?

# %%
fifanet_club_country = nx.Graph()
fifanet_club_country.add_nodes_from(fifa.club, bipartite=0)  # Clubs
fifanet_club_country.add_nodes_from(fifa.nationality, bipartite=1)  # Countries

# Add edges: Connect each club to the country of its players
fifanet_club_country.add_edges_from(zip(fifa.club, fifa.nationality))

# %%
# Get node sets
clubs = {n for n, d in fifanet_club_country.nodes(data=True) if d["bipartite"] == 0}
countries = set(fifanet_club_country) - clubs

# Create projected graphs
club_projection = nx.bipartite.weighted_projected_graph(fifanet_club_country, clubs)
country_projection = nx.bipartite.weighted_projected_graph(fifanet_club_country, countries)

# %%
import matplotlib.pyplot as plt

# Draw the club projection graph
pos = nx.spring_layout(club_projection, seed=42)  # Layout for better visualization
nx.draw(club_projection, pos, with_labels=True, node_size=50, font_size=8, edge_color="gray")

# %%
# Draw the country projection graph

pos = nx.spring_layout(country_projection, seed=42)  # Layout for better visualization
nx.draw(country_projection, pos, with_labels=True, node_size=100, font_size=8, edge_color="gray")

# %%
import os
examplesFolder = "MyGraphs/"
# Export club projection graph
nx.write_graphml(club_projection, os.path.join(examplesFolder, "fifa_club_projection.graphml"))
# Export country projection graph
nx.write_graphml(country_projection, os.path.join(examplesFolder, "fifa_country_projection.graphml"))
